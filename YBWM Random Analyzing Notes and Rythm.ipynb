# %%
from musicpy import *
import random
import matplotlib.pyplot as plt

# %%
#Define the Rests and Notes.

rest1o8  = rest(1/8)
rest1o4  = rest(1/4)
rest1o2  = rest(1/2)
rest4o4  = rest(4/4)
FSh31o8  = chord('F#3', interval = [1/8])
FSh31o4  = chord('F#3', interval = [1/4])
FSh33o8  = chord('F#3', interval = [3/8])
GSh31o8  = chord('G#3', interval = [1/8])
GSh31o4  = chord('G#3', interval = [1/4])
GSh31o2  = chord('G#3', interval = [1/2])
ASh31o8  = chord('A#3', interval = [1/8])
ASh31o4  = chord('A#3', interval = [1/4])
ASh31o2  = chord('A#3', interval = [1/2])
B31o8    = chord('B3' , interval = [1/8])
B31o4    = chord('B3' , interval = [1/4])
CSh41o8  = chord('C#4', interval = [1/8])
CSh41o4  = chord('C#4', interval = [1/4])
CSh43o8  = chord('C#4', interval = [3/8])
DSh41o8  = chord('D#4', interval = [1/8])
DSh41o4  = chord('D#4', interval = [1/4])
FSh41o8  = chord('F#4', interval = [1/8])
FSh41o4  = chord('F#4', interval = [1/4])
GSh41o8  = chord('G#4', interval = [1/8])
GSh41o4  = chord('G#4', interval = [1/4])
GSh41o2  = chord('G#4', interval = [1/2])
ASh41o16 = chord('A#4', interval = [1/16])
ASh41o8  = chord('A#4', interval = [1/8])
ASh41o4  = chord('A#4', interval = [1/4])
ASh43o8  = chord('A#4', interval = [3/8])
B41o16   = chord('B4',  interval = [1/16])
B41o8    = chord('B4',  interval = [1/8])
B41o4    = chord('B4',  interval = [1/4])
B43o8    = chord('B4',  interval = [3/8])
CSh51o8  = chord('C#5', interval = [1/8])

# %%
#Make a transition Dictionary.

YBWMD = {rest1o8 : [GSh31o8, CSh41o8, FSh41o8, FSh41o8, ASh41o8, ASh41o8, B41o8],
         rest1o4 : [rest1o8, rest1o8, rest1o4, rest1o4, rest1o2, rest1o2, rest1o2, CSh41o8, DSh41o4, ASh41o8, ASh41o8],
         rest1o2 : [rest1o4, rest1o4, rest1o4, rest4o4, rest4o4, ASh41o4, ASh41o4],
         rest4o4 : [rest1o2, rest4o4, rest4o4, rest4o4, rest4o4, rest4o4, rest4o4, rest4o4, CSh41o4, CSh41o4, CSh41o4],
         FSh31o8 : [FSh31o8, FSh31o8, CSh41o8, CSh41o8, CSh41o8, CSh41o4],
         FSh31o4 : [GSh31o2, GSh31o2],
         FSh33o8 : [GSh31o8, GSh31o8],
         GSh31o8 : [FSh31o8, FSh31o4, FSh31o4, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o4, ASh31o8, ASh31o8, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, B31o4, B31o4, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o4],
         GSh31o4 : [FSh31o8, FSh31o8, FSh31o8, B31o8, CSh41o8],
         GSh31o2 : [ASh31o2, ASh31o2],
         ASh31o8 : [FSh33o8, FSh33o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o4, GSh31o4, GSh31o4, GSh31o4, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o4, ASh31o4, ASh31o4, ASh31o4, B31o8, B31o8, B31o8, B31o4],
         ASh31o4 : [rest1o4, rest1o4, rest1o4, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, GSh31o8, ASh31o8, ASh31o8],
         ASh31o2 : [rest1o2, rest4o4],
         B31o8   : [ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, B31o8, B31o8, B31o8, B31o8, B31o8, B31o8, B31o8, B31o8, CSh41o8, CSh41o8, CSh41o8, CSh43o8, CSh43o8],
         B31o4   : [ASh31o8, ASh31o8, B31o8, B31o8, B31o8, B31o8, B31o8, B31o8, B31o8, B31o4, B31o4, B31o4, B31o4, B31o4],
         CSh41o8 : [rest1o8, rest1o8, ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, ASh31o4, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, CSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o4, DSh41o4, FSh41o4],
         CSh41o4 : [ASh31o8, ASh31o8, ASh31o8, ASh31o8, ASh31o4, FSh41o4, FSh41o4, B43o8, B43o8, B43o8, B43o8, B43o8, B43o8],
         CSh43o8 : [rest1o2, rest1o2],
         DSh41o8 : [CSh41o4, CSh41o4, CSh41o4, CSh41o4, CSh41o4, DSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o4, GSh41o4, GSh41o4, ASh41o4],
         DSh41o4 : [CSh41o4, DSh41o4, DSh41o4, DSh41o4, DSh41o4, DSh41o4, DSh41o4, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o4, FSh41o4, FSh41o4, FSh41o4, ASh41o4],
         FSh41o8 : [CSh41o8, CSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o4, DSh41o4, DSh41o4, DSh41o4, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o4, FSh41o4, FSh41o4, FSh41o4, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o4, GSh41o4, GSh41o4, ASh41o8, ASh41o8, ASh43o8],
         FSh41o4 : [rest1o8, CSh41o8, CSh41o4, CSh41o4, DSh41o8, DSh41o8, DSh41o8, DSh41o8, DSh41o4, DSh41o4, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o4, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o4, GSh41o4, GSh41o4, GSh41o4, GSh41o4, GSh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, B41o4, B43o8, B43o8, B43o8, B43o8, B43o8, B43o8],
         GSh41o8 : [FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o8, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o4, GSh41o4, GSh41o4, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, CSh51o8],
         GSh41o4 : [rest1o8, rest1o4, rest1o4, CSh41o8, CSh41o8, FSh41o8, FSh41o8, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, FSh41o4, GSh41o8, GSh41o8, ASh41o4],
         GSh41o2 : [rest1o8],
         ASh41o16: [GSh41o4],
         ASh41o8 : [rest1o4, FSh41o4, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o4, GSh41o4, GSh41o4, GSh41o4, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4, ASh41o4],
         ASh41o4 : [B31o4, B31o4, B31o4, B31o4, B31o4, B31o4, DSh41o4, DSh41o4, DSh41o4, DSh41o4, DSh41o4, DSh41o4, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o8, GSh41o4, GSh41o4, GSh41o4, GSh41o4, GSh41o4, GSh41o4, GSh41o4, GSh41o2],
         ASh43o8 : [B41o16],
         B41o16  : [ASh41o16],
         B41o8   : [ASh41o8, B41o8, B41o8, B41o4],
         B41o4   : [ASh41o8, B41o8],
         B43o8   : [ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8, ASh41o8],
         CSh51o8 : [ASh41o8, CSh51o8]
        }

# %%
#Pick the random state to start from.

possible_options = ['FSh31o8', 'FSh31o4', 'FSh33o8', 'GSh31o8', 'GSh31o4', 'GSh31o2', 'ASh31o8', 'ASh31o4', 'ASh31o2', 'B31o8', 'B31o4', 'CSh41o8', 'CSh41o4', 'CSh43o8', 'DSh41o8', 'DSh41o4', 'FSh41o8', 'FSh41o4', 'GSh41o8', 'GSh41o4', 'GSh41o2', 'ASh41o16', 'ASh41o8', 'ASh41o4', 'ASh43o8', 'B41o16', 'B41o8', 'B41o4', 'B43o8', 'CSh51o8']
random.choice(possible_options)
# Out:
# 'CSh51o8'

# %%
#Initialize a random state.

state = CSh51o8
newsong = 0

# %%
#Make a random song.

for i in range(81):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
verse1 = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(48):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
prechorus = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(44):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
chorus = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(4):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
instrumental1 = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(100):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
verse2 = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(12):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
instrumental2 = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(65):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
bridge = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(42):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
diffchorus = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(42):
    state = random.choice(YBWMD[state])
    print("state:",i,":",state)
    newsong += state
outro = newsong
newsong = 0  #Reset newsong for the next iteration
# Out:
# state: 0 : chord(notes=[A#4], interval=[1/8], start_time=0)
# state: 1 : chord(notes=[A#4], interval=[1/4], start_time=0)
# state: 2 : chord(notes=[G#4], interval=[1/8], start_time=0)
# state: 3 : chord(notes=[A#4], interval=[1/8], start_time=0)
# state: 4 : chord(notes=[G#4], interval=[1/8], start_time=0)
# state: 5 : chord(notes=[A#4], interval=[1/4], start_time=0)
# state: 6 : chord(notes=[G#4], interval=[1/8], start_time=0)
# state: 7 : chord(notes=[G#4], interval=[1/4], start_time=0)
# state: 8 : chord(notes=[F#4], interval=[1/4], start_time=0)
# state: 9 : chord(notes=[D#4], interval=[1/4], start_time=0)
# state: 10 : chord(notes=[F#4], interval=[1/4], start_time=0)
# state: 11 : chord(notes=[A#4], interval=[1/4], start_time=0)
# state: 12 : chord(notes=[G#4], interval=[1/2], start_time=0)
# state: 13 : rest(1/8)
# state: 14 : chord(notes=[F#4], interval=[1/8], start_time=0)
# state: 15 : chord(notes=[G#4], interval=[1/8], start_time=0)
# ...

# %%
YBWMR = verse1 + prechorus + chorus + instrumental1 + verse2 + prechorus + chorus + chorus + instrumental2 + bridge + diffchorus + chorus + outro

# Print the length of the final random song
print(len(YBWMR))
# Out:
# 581

# %%
for i in range(len(YBWMR)):
    print("state", [i] ,"note =", YBWMR.notes[i], "interval =", YBWMR.interval[i])
# Out:
# state [0] note = A#4 interval = 0.125
# state [1] note = A#4 interval = 0.25
# state [2] note = G#4 interval = 0.125
# state [3] note = A#4 interval = 0.125
# state [4] note = G#4 interval = 0.125
# state [5] note = A#4 interval = 0.25
# state [6] note = G#4 interval = 0.125
# state [7] note = G#4 interval = 0.25
# state [8] note = F#4 interval = 0.25
# state [9] note = D#4 interval = 0.25
# state [10] note = F#4 interval = 0.25
# state [11] note = A#4 interval = 0.25
# state [12] note = G#4 interval = 0.625
# state [13] note = F#4 interval = 0.125
# state [14] note = G#4 interval = 0.125
# state [15] note = F#4 interval = 0.125
# state [16] note = F#4 interval = 0.125
# state [17] note = A#4 interval = 0.125
# state [18] note = G#4 interval = 0.25
# state [19] note = F#4 interval = 0.25
# state [20] note = F#4 interval = 0.25
# state [21] note = G#4 interval = 0.125
# state [22] note = A#4 interval = 0.125
# state [23] note = G#4 interval = 0.125
# ...

# %%
play(YBWMR, bpm = 130, instrument = 25)

# %%
# print(YBWMR)

# %%
# print(YBWMR.notes)

# %%
# print(YBWMR.inteval)

# %% [markdown]
# #### Analysis of Random Song

# %% [markdown]
# Only the notes:

# %%
def PlotNoteFrequencies(NoteList):
    
    # Order notes
    note_order = ['A#3', 'A#4', 'B3', 'B4', 'C#4', 'C#5', 'D#4', 'F#3', 'F#4', 'G#3', 'G#4']      
    
    # Creating an empty dictionary
    SongDict = {}
 
    # Set assign the notes as dictionary keys: 
    for note in note_order:
        SongDict[note] = 0
        
    # Loop over the given note list again to give a value to the number of occurances. 
    for note in NoteList:
        snote = str(note)
        #print("note",note)
        if snote in SongDict:
            SongDict[snote] = SongDict[snote]+1

    print(SongDict)
    
    # Sort notes and frequencies
    Notes     = list(SongDict.keys())
    Frequency = [SongDict[note] for note in Notes]
 
    # creating the bar plot
    fig, ax = plt.subplots(figsize = (10, 5))
    bars = ax.bar(Notes, Frequency, color = "orange")
 
    for i in range(len(Notes)):
        ax.text(bars[i].get_x() + bars[i].get_width() / 2, bars[i].get_height(), str(Frequency[i]), ha='center', va='bottom')
       
    plt.xlabel("Note Used")
    plt.ylabel("Frequency in Song")
    plt.title("Frequency of Notes in Newly Generated You Belong With Me")
    plt.xticks(rotation = 45) 
    plt.show()
    fig.savefig("Random YBWM Note Frequencies.png", bbox_inches='tight')


PlotNoteFrequencies(YBWMR.notes)
# Out:
# {'A#3': 43, 'A#4': 106, 'B3': 21, 'B4': 32, 'C#4': 34, 'C#5': 1, 'D#4': 57, 'F#3': 5, 'F#4': 144, 'G#3': 42, 'G#4': 96}

# %% [markdown]
# Notes and their respective length:

# %%
formatted_notes = [' '.join([str(note), str(interval)]) for note, interval in zip(YBWMR, YBWMR.interval)]
# print(formatted_notes)

# %%
def PlotSpecificNoteFrequencies(NoteList):
           
    # Order specific notes
    specific_note_order = ['A#3 0.125', 'A#3 0.25', 'A#3 0.5', 'A#4 0.0625', 'A#4 0.125', 'A#4 0.25', 'A#4 0.375', 'B3 0.125', 'B3 0.25', 'B4 0.0625', 'B4 0.125', 'B4 0.25', 'B4 0.375', 'C#4 0.125', 'C#4 0.25', 'C#4 0.375', 'C#5 0.125', 'D#4 0.125', 'D#4 0.25', 'F#3 0.125', 'F#3 0.25', 'F#3 0.375', 'F#4 0.125', 'F#4 0.25', 'G#3 0.125', 'G#3 0.25', 'G#3 0.5', 'G#4 0.125', 'G#4 0.25', 'G#4 0.5']       

    # Creating an empty dictionary
    SongDict = {}
 
    # Set assign the notes as dictionary keys: 
    for note in specific_note_order:
        SongDict[note] = 0

    # Loop over the given note list again to give a value to the number of occurances. 
    for note in NoteList:
        snote = str(note)
#         print("note",note)
        if snote in SongDict:
            SongDict[snote] = SongDict[snote]+1

    print(SongDict)

    # Sort notes and frequencies
    Notes     = list(SongDict.keys())
    Frequency = [SongDict[note] for note in Notes]
  
    # creating the bar plot
    fig, ax = plt.subplots(figsize = (10, 5))
    bars = ax.bar(Notes, Frequency, color = "orange")
    
    for i in range(len(Notes)):
        ax.text(bars[i].get_x() + bars[i].get_width() / 2, bars[i].get_height(), str(Frequency[i]), ha='center', va='bottom')
    
    plt.xlabel("Specific Note Type Used")
    plt.ylabel("Frequency in Song")
    plt.title("Frequency of Specific Note Types in Newly Generated You Belong With Me")
    plt.xticks(rotation = 80) 
    plt.show()
    fig.savefig("Random YBWM Specific Note Type Frequencies.png", bbox_inches='tight')


PlotSpecificNoteFrequencies(formatted_notes)
# Out:
# {'A#3 0.125': 31, 'A#3 0.25': 7, 'A#3 0.5': 1, 'A#4 0.0625': 4, 'A#4 0.125': 61, 'A#4 0.25': 37, 'A#4 0.375': 4, 'B3 0.125': 12, 'B3 0.25': 9, 'B4 0.0625': 4, 'B4 0.125': 6, 'B4 0.25': 8, 'B4 0.375': 14, 'C#4 0.125': 22, 'C#4 0.25': 9, 'C#4 0.375': 0, 'C#5 0.125': 1, 'D#4 0.125': 30, 'D#4 0.25': 27, 'F#3 0.125': 5, 'F#3 0.25': 0, 'F#3 0.375': 0, 'F#4 0.125': 97, 'F#4 0.25': 46, 'G#3 0.125': 37, 'G#3 0.25': 5, 'G#3 0.5': 0, 'G#4 0.125': 63, 'G#4 0.25': 25, 'G#4 0.5': 0}

# %% [markdown]
# Length of all notes:

# %%
def PlotNoteLengthFrequencies(LengthList):
    
    # Order lenths
    length_order = ['0.0625', '0.125', '0.25', '0.375', '0.5']

    # Creating an empty dictionary
    SongDict = {}
 
    # Set assign the rhythms as dictionary keys: 
    for length in length_order:
        SongDict[length] = 0
        
    # Loop over the given rhythm list again to give a value to the number of occurances. 
    for length in LengthList:
        slength = str(length)
        #print("length",length)
        if slength in SongDict:
            SongDict[slength] = SongDict[slength]+1
            
    print(SongDict)
    
    # Sort notes and frequencies
    Notes     = list(SongDict.keys())
    Frequency = [SongDict[note] for note in Notes]
 
    # creating the bar plot
    fig, ax = plt.subplots(figsize = (10, 5))
    bars = ax.bar(Notes, Frequency, color = "orange")
    
    for i in range(len(Notes)):
        ax.text(bars[i].get_x() + bars[i].get_width() / 2, bars[i].get_height(), str(Frequency[i]), ha='center', va='bottom')
    
    plt.xlabel("Length of Note")
    plt.ylabel("Frequency in Song")
    plt.title("Frequency of Note Lengths in Newly Generated You Belong With Me")
    plt.xticks(rotation = 45)
    plt.show()
    fig.savefig("Random YBWM Length of Notes Frequencies.png", bbox_inches='tight')


PlotNoteLengthFrequencies(YBWMR.interval)
# Out:
# {'0.0625': 8, '0.125': 365, '0.25': 173, '0.375': 20, '0.5': 1}
