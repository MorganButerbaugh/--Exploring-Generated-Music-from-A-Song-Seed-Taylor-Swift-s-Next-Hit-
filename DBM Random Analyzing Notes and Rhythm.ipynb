# %%
from musicpy import *
import random
import matplotlib.pyplot as plt

# %%
def ASCIItoNote(note):
    if note == 'rest1o32': 
        return rest(1/32)
    if note == 'rest1o8':
        return rest(1/8)
    if note == 'rest1o4':
        return rest(1/4)
    if note == 'rest1o2':
        return rest(1/2)
    if note == 'rest4o4':
        return rest(4/4)
    if note == 'D31o8':
        return chord('D3', interval = [1/8])
    if note == 'D31o4':
        return chord('D3', interval = [1/4])
    if note == 'E31o4':
        return chord('E3', interval = [1/4])
    if note == 'G31o8':
        return chord('G3', interval = [1/8])
    if note == 'A33o16':
        return chord('A3', interval = [3/16])
    if note == 'A31o8':
        return chord('A3', interval = [1/8])
    if note == 'A31o4':
        return chord('A3', interval = [1/4])
    if note == 'A33o8':
        return chord('A3', interval = [3/8])
    if note == 'A31o12':
        return chord('A3', interval = [1/12])
    if note == 'B33o8':
        return chord('B3', interval = [3/8])
    if note == 'C41o8':
        return chord('C4', interval = [1/8])
    if note == 'C41o4':
        return chord('C4', interval = [1/4])
    if note == 'C43o8':
        return chord('C4', interval = [3/8])
    if note == 'C41o12':
        return chord('C4', interval = [1/12])
    if note == 'C41o6':
        return chord('C4', interval = [1/6])
    if note == 'D41o8':
        return chord('D4', interval = [1/8])
    if note == 'D41o4':
        return chord('D4', interval = [1/4])
    if note == 'D43o8':
        return chord('D4', interval = [3/8])
    if note == 'D41o12':
        return chord('D4', interval = [1/12])
    if note == 'D41o6':
        return chord('D4', interval = [1/6])
    if note == 'Eb41o4':
        return chord('Eb4', interval = [1/4])
    if note == 'E41o8':
        return chord('E4', interval = [1/8])
    if note == 'E41o4':
        return chord('E4', interval = [1/4])
    if note == 'E41o12':
        return chord('E4', interval = [1/12])
    if note == 'E41o6':
        return chord('E4', interval = [1/6])
    if note == 'G41o4':
        return chord('G4', interval = [1/4])
    if note == 'A43o16':
        return chord('A4', interval = [3/16])
    if note == 'A41o8':
        return chord('A4', interval = [1/8])
    if note == 'A41o4':
        return chord('A4', interval = [1/4])
    if note == 'A41o6':
        return chord('A4', interval = [1/6])
    if note == 'A41o12':
        return chord('A4', interval = [1/12])
    if note == 'C51o8':
        return chord('C5', interval = [1/8])
    if note == 'C51o4':
        return chord('C5', interval = [1/4])
    if note == 'C51o2':
        chord('C5', interval = [1/2])
    if note == 'C51o12':
        return chord('C5', interval = [1/12])
    if note == 'D51o8':
        return chord('D5', interval = [1/8])
    if note == 'D51o4':
        return chord('D5', interval = [1/4])
    if note == 'D51o12':
        return chord('D5', interval = [1/12])
    if note == 'E51o8':
        return chord('E5', interval = [1/8])
    if note == 'E51o4':
        return chord('E5', interval = [1/4])
    if note == 'E51o2':
        return chord('E5', interval = [1/2])
    if note == 'E51o12':
        return chord('E5', interval = [1/12])

# %%
# Transition Dictionary

#make the song into a sring and then a list
songstr = '...'
songList = songstr.split("+")
# print(songList)

song = songList

states = []
DBMD = {}

for notetype in song:
    if notetype not in states:
        states.append(notetype)
        DBMD[notetype] = []

for i, notetype in enumerate(song):
    #print("notetype",notetype,"i",i)
    if (i < len(song) - 1):
        DBMD[notetype].append(song[i + 1])

print(DBMD)
# Out:
# {'C41o4': ['A31o8', 'C41o8', 'A31o4', 'A31o4', 'D41o8', 'A31o4', 'A31o4', 'D41o8', 'A31o4', 'A31o4', 'D41o8', 'A31o8', 'C41o8', 'A31o8', 'C41o8', 'C41o6', 'A31o4', 'A31o4', 'D41o8', 'A31o4', 'A31o4', 'D41o8', 'A31o4', 'A31o4', 'D41o8', 'A31o8', 'C41o8', 'A31o8', 'C41o8', 'A31o8', 'C41o8', 'A31o8', 'C41o8'], 'A31o8': ['A31o4', 'A31o8', 'A31o8', 'C41o8', 'A31o8', 'G31o8', 'C43o8', 'G31o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'C43o8', 'A33o8', 'A33o8', 'A31o4', 'A31o8', 'A31o8', 'C41o8', 'A31o8', 'G31o8', 'C43o8', 'G31o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'C43o8', 'A31o4', 'A31o8', 'A31o8', 'C41o8', 'A31o8', 'G31o8', 'C43o8', 'G31o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'C43o8', 'A31o4', 'D31o4', 'A31o4', 'A31o8', 'A31o8', 'C41o8', 'A31o8', 'G31o8', 'C43o8', 'G31o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'C43o8', 'A31o4', 'A31o8', 'A31o8', 'C41o8', 'A31o8', 'G31o8', 'C43o8', 'G31o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'C43o8', 'G31o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'A31o4', 'A31o8', 'A31o8', 'C41o8', 'A31o8', 'G31o8', 'C43o8', 'A31o8', 'C41o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'C43o8', 'A31o4', 'A31o8', 'A31o8', 'C41o8', 'A31o8', 'G31o8', 'C43o8', 'G31o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'C43o8', 'G31o8', 'A31o8', 'G31o8', 'A31o8', 'G31o8', 'C43o8'], 'A31o4': ['C41o8', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o8', 'C41o8', 'A31o8', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o4', 'C41o8', 'C41o8', 'rest1o4', 'A41o6', 'rest1o4', 'rest1o2', 'rest1o2', 'C41o8', 'C41o8'], 'C41o8': ['C41o4', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'C41o8', 'C41o8', 'D41o8', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8', 'D41o8', 'D41o4', 'D41o8', 'D41o8', 'E41o4', 'C43o8', 'D41o8', 'D41o4', 'D41o8', 'D41o8', 'D41o8', 'E41o4', 'C43o8', 'A31o4', 'D41o8', 'D41o8', 'D41o4', 'A33o16', 'C41o4', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'C41o8', 'C41o8', 'D41o8', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8', 'C41o4', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'C41o8', 'C41o8', 'D41o8', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8', 'D41o8', 'D41o8', 'Eb41o4', 'D41o8', 'D41o8', 'E41o4', 'C43o8', 'B33o8', 'D41o8', 'D41o8', 'Eb41o4', 'D41o8', 'D41o8', 'E41o4', 'C41o4', 'D41o8', 'D41o8', 'A31o4', 'D41o8', 'D41o8', 'D41o4', 'A33o16', 'C41o4', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'C41o8', 'C41o8', 'D41o8', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8', 'C41o4', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'C41o8', 'C41o8', 'D41o8', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8', 'D41o12', 'D41o12', 'D41o12', 'D41o12', 'D41o12', 'D41o12', 'D41o12', 'D41o12', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8', 'C41o4', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'C41o8', 'C41o8', 'D41o8', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8', 'C41o4', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'C41o8', 'C41o8', 'D41o8', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8', 'C41o8', 'D41o8', 'A31o8', 'A31o8', 'A31o8'], 'D41o8': ['A31o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8', 'D43o8', 'C41o8', 'C41o8', 'D43o8', 'C41o8', 'C41o8', 'C41o8', 'D43o8', 'D43o8', 'C41o8', 'C41o8', 'D43o8', 'C41o8', 'C41o8', 'C41o8', 'D43o8', 'E41o8', 'C41o8', 'E41o8', 'E41o8', 'E41o8', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8', 'A31o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8', 'D43o8', 'C41o8', 'C41o8', 'C41o8', 'D43o8', 'C41o8', 'C41o8', 'C41o8', 'D43o8', 'D41o4', 'D43o8', 'C41o8', 'C41o8', 'C41o8', 'D43o8', 'C41o8', 'C41o8', 'C41o8', 'D41o8', 'D41o8', 'D41o8', 'D41o8', 'C41o8', 'C41o8', 'E41o8', 'C41o8', 'E41o8', 'E41o8', 'E41o8', 'C41o8', 'C41o8', 'A31o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8', 'A31o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8', 'C41o8', 'C41o8', 'C41o8', 'C41o8', 'C41o8', 'C41o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8', 'A31o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8', 'A31o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8', 'C41o8', 'D41o4', 'E41o8', 'C41o8'], 'G31o8': ['A31o8', 'C41o8', 'C41o8', 'A31o8', 'A31o8', 'C41o8', 'C41o8', 'A31o8', 'A31o8', 'C41o8', 'C41o8', 'A31o8', ...

# %%
#Pick the random state to start from.
keyList = []

for i, key in enumerate(DBMD):
    keyList.append(key)
#     print("key", i, " = ", key)
#     print("      ", DBMD[key])

possible_options = keyList
# print(possible_options)

# %%
#Initialize a random song.
state = random.choice(possible_options)
newsong = ASCIItoNote(state)

# %%
#Make a random song.

for i in range(47):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
introchorus = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(66):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
verse1 = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(40):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
prechorus = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(96):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
chorus = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(80):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
verse2 = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(28):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
riff = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(19):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
solo = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(38):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
bridge = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(30):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
diffriff = newsong
newsong = 0  #Reset newsong for the next iteration

for i in range(24):
    state = random.choice(DBMD[state])
    myNote = ASCIItoNote(state)
    print("state", i,':',  myNote)
    newsong += myNote
outro = newsong
newsong = 0  #Reset newsong for the next iteration
# Out:
# state 0 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 1 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 2 : chord(notes=[A4], interval=[1/6], start_time=0)
# state 3 : chord(notes=[A4], interval=[1/6], start_time=0)
# state 4 : chord(notes=[A4], interval=[1/6], start_time=0)
# state 5 : chord(notes=[A4], interval=[1/4], start_time=0)
# state 6 : rest(1/4)
# state 7 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 8 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 9 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 10 : rest(1/2)
# state 11 : rest(1/4)
# state 12 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 13 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 14 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 15 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 16 : chord(notes=[Eb4], interval=[1/4], start_time=0)
# state 17 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 18 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 19 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 20 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 21 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 22 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 23 : chord(notes=[D4], interval=[1/12], start_time=0)
# state 24 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 25 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 26 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 27 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 28 : rest(1/2)
# state 29 : rest(1/4)
# state 30 : rest(1/8)
# state 31 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 32 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 33 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 34 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 35 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 36 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 37 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 38 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 39 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 40 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 41 : rest(1/2)
# state 42 : rest(1/4)
# state 43 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 44 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 45 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 46 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 0 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 1 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 2 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 3 : chord(notes=[D4], interval=[3/8], start_time=0)
# state 4 : rest(1/2)
# state 5 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 6 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 7 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 8 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 9 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 10 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 11 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 12 : chord(notes=[D3], interval=[1/4], start_time=0)
# state 13 : chord(notes=[E3], interval=[1/4], start_time=0)
# state 14 : rest(1/4)
# state 15 : chord(notes=[C5], interval=[1/4], start_time=0)
# state 16 : rest(1/4)
# state 17 : rest(1/8)
# state 18 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 19 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 20 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 21 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 22 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 23 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 24 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 25 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 26 : rest(1/2)
# state 27 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 28 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 29 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 30 : chord(notes=[D4], interval=[1/12], start_time=0)
# state 31 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 32 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 33 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 34 : chord(notes=[D4], interval=[3/8], start_time=0)
# state 35 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 36 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 37 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 38 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 39 : chord(notes=[Eb4], interval=[1/4], start_time=0)
# state 40 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 41 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 42 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 43 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 44 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 45 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 46 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 47 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 48 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 49 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 50 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 51 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 52 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 53 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 54 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 55 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 56 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 57 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 58 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 59 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 60 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 61 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 62 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 63 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 64 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 65 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 0 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 1 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 2 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 3 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 4 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 5 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 6 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 7 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 8 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 9 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 10 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 11 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 12 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 13 : chord(notes=[D4], interval=[3/8], start_time=0)
# state 14 : rest(1/4)
# state 15 : chord(notes=[C5], interval=[1/4], start_time=0)
# state 16 : rest(1/4)
# state 17 : rest(1/8)
# state 18 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 19 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 20 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 21 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 22 : chord(notes=[A3], interval=[3/8], start_time=0)
# state 23 : chord(notes=[D3], interval=[1/8], start_time=0)
# state 24 : chord(notes=[D3], interval=[1/8], start_time=0)
# state 25 : chord(notes=[D3], interval=[1/8], start_time=0)
# state 26 : chord(notes=[D3], interval=[1/8], start_time=0)
# state 27 : chord(notes=[D3], interval=[1/8], start_time=0)
# state 28 : chord(notes=[D3], interval=[1/8], start_time=0)
# state 29 : chord(notes=[E3], interval=[1/4], start_time=0)
# state 30 : rest(1)
# state 31 : chord(notes=[D4], interval=[1/12], start_time=0)
# state 32 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 33 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 34 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 35 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 36 : rest(1/2)
# state 37 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 38 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 39 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 0 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 1 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 2 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 3 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 4 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 5 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 6 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 7 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 8 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 9 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 10 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 11 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 12 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 13 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 14 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 15 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 16 : chord(notes=[D4], interval=[1/12], start_time=0)
# state 17 : chord(notes=[C4], interval=[1/12], start_time=0)
# state 18 : chord(notes=[A3], interval=[1/12], start_time=0)
# state 19 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 20 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 21 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 22 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 23 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 24 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 25 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 26 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 27 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 28 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 29 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 30 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 31 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 32 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 33 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 34 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 35 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 36 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 37 : chord(notes=[B3], interval=[3/8], start_time=0)
# state 38 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 39 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 40 : rest(1/4)
# state 41 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 42 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 43 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 44 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 45 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 46 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 47 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 48 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 49 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 50 : chord(notes=[A3], interval=[3/8], start_time=0)
# state 51 : chord(notes=[D3], interval=[1/8], start_time=0)
# state 52 : chord(notes=[E3], interval=[1/4], start_time=0)
# state 53 : rest(1/4)
# state 54 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 55 : chord(notes=[C4], interval=[1/6], start_time=0)
# state 56 : chord(notes=[D4], interval=[1/6], start_time=0)
# state 57 : chord(notes=[E4], interval=[1/6], start_time=0)
# state 58 : rest(1/4)
# state 59 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 60 : chord(notes=[C4], interval=[1/6], start_time=0)
# state 61 : chord(notes=[D4], interval=[1/6], start_time=0)
# state 62 : chord(notes=[E4], interval=[1/6], start_time=0)
# state 63 : rest(1/4)
# state 64 : chord(notes=[E5], interval=[1/2], start_time=0)
# state 65 : chord(notes=[D5], interval=[1/12], start_time=0)
# state 66 : chord(notes=[C5], interval=[1/12], start_time=0)
# state 67 : chord(notes=[A4], interval=[1/12], start_time=0)
# state 68 : chord(notes=[A4], interval=[1/8], start_time=0)
# state 69 : chord(notes=[C5], interval=[1/8], start_time=0)
# state 70 : chord(notes=[D5], interval=[1/12], start_time=0)
# state 71 : chord(notes=[E5], interval=[1/12], start_time=0)
# state 72 : chord(notes=[D5], interval=[1/12], start_time=0)
# state 73 : chord(notes=[D5], interval=[1/8], start_time=0)
# state 74 : chord(notes=[C5], interval=[1/8], start_time=0)
# state 75 : chord(notes=[D5], interval=[1/8], start_time=0)
# state 76 : chord(notes=[E5], interval=[1/8], start_time=0)
# state 77 : chord(notes=[D5], interval=[1/4], start_time=0)
# state 78 : chord(notes=[C5], interval=[1/8], start_time=0)
# state 79 : chord(notes=[C5], interval=[1/8], start_time=0)
# state 80 : chord(notes=[A4], interval=[3/16], start_time=0)
# state 81 : rest(1/32)
# state 82 : rest(1/4)
# state 83 : rest(1/8)
# state 84 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 85 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 86 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 87 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 88 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 89 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 90 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 91 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 92 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 93 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 94 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 95 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 0 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 1 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 2 : chord(notes=[Eb4], interval=[1/4], start_time=0)
# state 3 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 4 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 5 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 6 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 7 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 8 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 9 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 10 : chord(notes=[A3], interval=[3/8], start_time=0)
# state 11 : chord(notes=[D3], interval=[1/8], start_time=0)
# state 12 : chord(notes=[E3], interval=[1/4], start_time=0)
# state 13 : rest(1)
# state 14 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 15 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 16 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 17 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 18 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 19 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 20 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 21 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 22 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 23 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 24 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 25 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 26 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 27 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 28 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 29 : chord(notes=[D4], interval=[3/8], start_time=0)
# state 30 : rest(1/2)
# state 31 : rest(1/2)
# state 32 : rest(1)
# state 33 : rest(1/2)
# state 34 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 35 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 36 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 37 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 38 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 39 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 40 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 41 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 42 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 43 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 44 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 45 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 46 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 47 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 48 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 49 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 50 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 51 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 52 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 53 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 54 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 55 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 56 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 57 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 58 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 59 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 60 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 61 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 62 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 63 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 64 : chord(notes=[A4], interval=[1/6], start_time=0)
# state 65 : chord(notes=[A4], interval=[1/4], start_time=0)
# state 66 : rest(1/4)
# state 67 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 68 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 69 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 70 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 71 : chord(notes=[D4], interval=[3/8], start_time=0)
# state 72 : rest(1/2)
# state 73 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 74 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 75 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 76 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 77 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 78 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 79 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 0 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 1 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 2 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 3 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 4 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 5 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 6 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 7 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 8 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 9 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 10 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 11 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 12 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 13 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 14 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 15 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 16 : rest(1/4)
# state 17 : chord(notes=[E4], interval=[1/4], start_time=0)
# state 18 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 19 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 20 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 21 : rest(1/2)
# state 22 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 23 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 24 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 25 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 26 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 27 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 0 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 1 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 2 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 3 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 4 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 5 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 6 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 7 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 8 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 9 : rest(1/2)
# state 10 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 11 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 12 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 13 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 14 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 15 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 16 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 17 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 18 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 0 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 1 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 2 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 3 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 4 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 5 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 6 : chord(notes=[C5], interval=[1/8], start_time=0)
# state 7 : chord(notes=[E5], interval=[1/8], start_time=0)
# state 8 : chord(notes=[D5], interval=[1/4], start_time=0)
# state 9 : chord(notes=[C5], interval=[1/8], start_time=0)
# state 10 : chord(notes=[C5], interval=[1/8], start_time=0)
# state 11 : chord(notes=[D5], interval=[1/4], start_time=0)
# state 12 : None
# state 13 : chord(notes=[G4], interval=[1/4], start_time=0)
# state 14 : rest(1/8)
# state 15 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 16 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 17 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 18 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 19 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 20 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 21 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 22 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 23 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 24 : chord(notes=[D4], interval=[1/12], start_time=0)
# state 25 : chord(notes=[E4], interval=[1/12], start_time=0)
# state 26 : chord(notes=[D4], interval=[1/12], start_time=0)
# state 27 : chord(notes=[E4], interval=[1/12], start_time=0)
# state 28 : chord(notes=[D4], interval=[1/12], start_time=0)
# state 29 : chord(notes=[C4], interval=[1/12], start_time=0)
# state 30 : chord(notes=[A3], interval=[1/12], start_time=0)
# state 31 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 32 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 33 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 34 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 35 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 36 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 37 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 0 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 1 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 2 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 3 : chord(notes=[A4], interval=[1/6], start_time=0)
# state 4 : chord(notes=[A4], interval=[1/6], start_time=0)
# state 5 : chord(notes=[A4], interval=[1/6], start_time=0)
# state 6 : chord(notes=[A4], interval=[1/4], start_time=0)
# state 7 : rest(1/4)
# state 8 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 9 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 10 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 11 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 12 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 13 : chord(notes=[A3], interval=[1/4], start_time=0)
# state 14 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 15 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 16 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 17 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 18 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 19 : chord(notes=[C4], interval=[1/4], start_time=0)
# state 20 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 21 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 22 : chord(notes=[Eb4], interval=[1/4], start_time=0)
# state 23 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 24 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 25 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 26 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 27 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 28 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 29 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 0 : chord(notes=[C4], interval=[3/8], start_time=0)
# state 1 : rest(1/2)
# state 2 : rest(1/4)
# state 3 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 4 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 5 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 6 : chord(notes=[D4], interval=[1/4], start_time=0)
# state 7 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 8 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 9 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 10 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 11 : chord(notes=[G3], interval=[1/8], start_time=0)
# state 12 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 13 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 14 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 15 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 16 : chord(notes=[A3], interval=[1/8], start_time=0)
# state 17 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 18 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 19 : chord(notes=[E4], interval=[1/8], start_time=0)
# state 20 : chord(notes=[D4], interval=[1/8], start_time=0)
# state 21 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 22 : chord(notes=[C4], interval=[1/8], start_time=0)
# state 23 : chord(notes=[D4], interval=[1/8], start_time=0)

# %%
DBMR = introchorus+ verse1 + prechorus + chorus + verse2 + prechorus + chorus + riff + riff + solo + bridge + chorus + diffriff + outro

# Print the length of the final random song
print(len(DBMR))
# Out:
# 667

# %%
for i in range(len(DBMR)):
    print("state", [i] ,"note =", DBMR.notes[i], "interval =", DBMR.interval[i])
# Out:
# state [0] note = C4 interval = 0.25
# state [1] note = A3 interval = 0.25
# state [2] note = A4 interval = 0.16666666666666666
# state [3] note = A4 interval = 0.16666666666666666
# state [4] note = A4 interval = 0.16666666666666666
# state [5] note = A4 interval = 0.5
# state [6] note = C4 interval = 0.25
# state [7] note = A3 interval = 0.125
# state [8] note = C4 interval = 1.125
# state [9] note = C4 interval = 0.25
# state [10] note = D4 interval = 0.125
# state [11] note = C4 interval = 0.125
# state [12] note = D4 interval = 0.25
# state [13] note = Eb4 interval = 0.25
# state [14] note = D4 interval = 0.125
# state [15] note = C4 interval = 0.125
# state [16] note = C4 interval = 0.125
# state [17] note = C4 interval = 0.125
# state [18] note = C4 interval = 0.125
# state [19] note = C4 interval = 0.125
# state [20] note = D4 interval = 0.08333333333333333
# state [21] note = D4 interval = 0.125
# state [22] note = C4 interval = 0.125
# state [23] note = C4 interval = 0.125
# state [24] note = A3 interval = 1.125
# state [25] note = C4 interval = 0.125
# state [26] note = E4 interval = 0.25
# state [27] note = D4 interval = 0.125
# state [28] note = C4 interval = 0.125
# state [29] note = C4 interval = 0.125
# state [30] note = A3 interval = 0.125
# state [31] note = C4 interval = 0.125
# state [32] note = C4 interval = 0.125
# state [33] note = C4 interval = 0.125
# state [34] note = C4 interval = 1.125
# state [35] note = E4 interval = 0.25
# state [36] note = D4 interval = 0.125
# state [37] note = E4 interval = 0.125
# state [38] note = E4 interval = 0.25
# state [39] note = D4 interval = 0.125
# state [40] note = C4 interval = 0.125
# state [41] note = D4 interval = 0.125
# state [42] note = D4 interval = 0.875
# state [43] note = D4 interval = 0.125
# state [44] note = E4 interval = 0.125
# state [45] note = D4 interval = 0.25
# state [46] note = D4 interval = 0.125
# state [47] note = A3 interval = 0.125
# state [48] note = A3 interval = 0.125
# state [49] note = A3 interval = 0.125
# state [50] note = D3 interval = 0.25
# state [51] note = E3 interval = 0.5
# state [52] note = C5 interval = 0.625
# state [53] note = C4 interval = 0.125
# state [54] note = C4 interval = 0.125
# state [55] note = A3 interval = 0.125
# state [56] note = C4 interval = 0.125
# state [57] note = D4 interval = 0.25
# state [58] note = D4 interval = 0.125
# state [59] note = A3 interval = 0.125
# state [60] note = C4 interval = 0.875
# state [61] note = D4 interval = 0.125
# state [62] note = C4 interval = 0.125
# state [63] note = C4 interval = 0.125
# state [64] note = D4 interval = 0.08333333333333333
# state [65] note = D4 interval = 0.125
# state [66] note = C4 interval = 0.125
# state [67] note = D4 interval = 0.125
# state [68] note = D4 interval = 0.375
# state [69] note = C4 interval = 0.125
# state [70] note = C4 interval = 0.125
# state [71] note = D4 interval = 0.125
# state [72] note = C4 interval = 0.125
# state [73] note = Eb4 interval = 0.25
# state [74] note = D4 interval = 0.125
# state [75] note = E4 interval = 0.125
# state [76] note = D4 interval = 0.125
# state [77] note = E4 interval = 0.125
# state [78] note = D4 interval = 0.125
# state [79] note = E4 interval = 0.125
# state [80] note = D4 interval = 0.25
# state [81] note = A3 interval = 0.25
# state [82] note = C4 interval = 0.25
# state [83] note = A3 interval = 0.25
# state [84] note = C4 interval = 0.125
# state [85] note = D4 interval = 0.125
# state [86] note = C4 interval = 0.125
# state [87] note = A3 interval = 0.125
# state [88] note = A3 interval = 0.125
# state [89] note = A3 interval = 0.125
# state [90] note = G3 interval = 0.125
# state [91] note = A3 interval = 0.125
# state [92] note = A3 interval = 0.125
# state [93] note = G3 interval = 0.125
# state [94] note = C4 interval = 0.125
# state [95] note = D4 interval = 0.125
# state [96] note = C4 interval = 0.125
# state [97] note = D4 interval = 0.125
# state [98] note = C4 interval = 0.125
# state [99] note = E4 interval = 0.25
# state [100] note = D4 interval = 0.125
# state [101] note = C4 interval = 0.125
# state [102] note = D4 interval = 0.125
# state [103] note = C4 interval = 0.125
# state [104] note = C4 interval = 0.125
# state [105] note = C4 interval = 0.25
# state [106] note = D4 interval = 0.125
# state [107] note = E4 interval = 0.125
# state [108] note = E4 interval = 0.25
# state [109] note = D4 interval = 0.125
# state [110] note = C4 interval = 0.125
# state [111] note = E4 interval = 0.25
# state [112] note = D4 interval = 0.125
# state [113] note = D4 interval = 0.625
# state [114] note = C5 interval = 0.625
# state [115] note = C4 interval = 0.125
# state [116] note = C4 interval = 0.125
# state [117] note = A3 interval = 0.125
# state [118] note = A3 interval = 0.125
# state [119] note = A3 interval = 0.375
# state [120] note = D3 interval = 0.125
# state [121] note = D3 interval = 0.125
# state [122] note = D3 interval = 0.125
# state [123] note = D3 interval = 0.125
# state [124] note = D3 interval = 0.125
# state [125] note = D3 interval = 0.125
# state [126] note = E3 interval = 1.25
# state [127] note = D4 interval = 0.08333333333333333
# state [128] note = D4 interval = 0.125
# state [129] note = C4 interval = 0.125
# state [130] note = A3 interval = 0.125
# state [131] note = C4 interval = 0.875
# state [132] note = D4 interval = 0.125
# state [133] note = C4 interval = 0.125
# state [134] note = A3 interval = 0.125
# state [135] note = G3 interval = 0.125
# state [136] note = C4 interval = 0.125
# state [137] note = A3 interval = 0.125
# state [138] note = G3 interval = 0.125
# state [139] note = A3 interval = 0.125
# state [140] note = A3 interval = 0.125
# state [141] note = A3 interval = 0.125
# state [142] note = A3 interval = 0.125
# state [143] note = G3 interval = 0.125
# state [144] note = A3 interval = 0.125
# state [145] note = A3 interval = 0.125
# state [146] note = A3 interval = 0.125
# state [147] note = A3 interval = 0.125
# state [148] note = A3 interval = 0.125
# state [149] note = G3 interval = 0.125
# state [150] note = C4 interval = 0.125
# state [151] note = D4 interval = 0.08333333333333333
# state [152] note = C4 interval = 0.08333333333333333
# state [153] note = A3 interval = 0.08333333333333333
# state [154] note = A3 interval = 0.25
# state [155] note = C4 interval = 0.25
# state [156] note = D4 interval = 0.125
# state [157] note = E4 interval = 0.125
# state [158] note = D4 interval = 0.125
# state [159] note = A3 interval = 0.125
# state [160] note = A3 interval = 0.125
# state [161] note = A3 interval = 0.125
# state [162] note = G3 interval = 0.125
# state [163] note = A3 interval = 0.125
# state [164] note = A3 interval = 0.25
# state [165] note = C4 interval = 0.125
# state [166] note = D4 interval = 0.125
# state [167] note = A3 interval = 0.125
# state [168] note = A3 interval = 0.125
# state [169] note = C4 interval = 0.125
# state [170] note = A3 interval = 0.25
# state [171] note = C4 interval = 0.125
# state [172] note = B3 interval = 0.375
# state [173] note = D4 interval = 0.125
# state [174] note = D4 interval = 0.5
# state [175] note = E4 interval = 0.25
# state [176] note = E4 interval = 0.25
# state [177] note = D4 interval = 0.125
# state [178] note = E4 interval = 0.125
# state [179] note = D4 interval = 0.125
# state [180] note = C4 interval = 0.125
# state [181] note = A3 interval = 0.125
# state [182] note = G3 interval = 0.125
# state [183] note = A3 interval = 0.125
# state [184] note = A3 interval = 0.375
# state [185] note = D3 interval = 0.125
# state [186] note = E3 interval = 0.5
# state [187] note = C4 interval = 0.25
# state [188] note = C4 interval = 0.16666666666666666
# state [189] note = D4 interval = 0.16666666666666666
# state [190] note = E4 interval = 0.41666666666666663
# state [191] note = C4 interval = 0.25
# state [192] note = C4 interval = 0.16666666666666666
# state [193] note = D4 interval = 0.16666666666666666
# state [194] note = E4 interval = 0.41666666666666663
# state [195] note = E5 interval = 0.5
# state [196] note = D5 interval = 0.08333333333333333
# state [197] note = C5 interval = 0.08333333333333333
# state [198] note = A4 interval = 0.08333333333333333
# state [199] note = A4 interval = 0.125
# state [200] note = C5 interval = 0.125
# state [201] note = D5 interval = 0.08333333333333333
# state [202] note = E5 interval = 0.08333333333333333
# state [203] note = D5 interval = 0.08333333333333333
# state [204] note = D5 interval = 0.125
# state [205] note = C5 interval = 0.125
# state [206] note = D5 interval = 0.125
# state [207] note = E5 interval = 0.125
# state [208] note = D5 interval = 0.25
# state [209] note = C5 interval = 0.125
# state [210] note = C5 interval = 0.125
# state [211] note = A4 interval = 0.59375
# state [212] note = E4 interval = 0.125
# state [213] note = D4 interval = 0.125
# state [214] note = C4 interval = 0.125
# state [215] note = A3 interval = 0.125
# state [216] note = G3 interval = 0.125
# state [217] note = A3 interval = 0.125
# state [218] note = C4 interval = 0.125
# state [219] note = D4 interval = 0.125
# state [220] note = C4 interval = 0.125
# state [221] note = A3 interval = 0.125
# state [222] note = A3 interval = 0.25
# state [223] note = C4 interval = 0.125
# state [224] note = D4 interval = 0.125
# state [225] note = D4 interval = 0.25
# state [226] note = Eb4 interval = 0.25
# state [227] note = D4 interval = 0.125
# state [228] note = C4 interval = 0.125
# state [229] note = D4 interval = 0.125
# state [230] note = C4 interval = 0.125
# state [231] note = C4 interval = 0.125
# state [232] note = C4 interval = 0.125
# state [233] note = A3 interval = 0.125
# state [234] note = A3 interval = 0.375
# state [235] note = D3 interval = 0.125
# state [236] note = E3 interval = 1.25
# state [237] note = D4 interval = 0.125
# state [238] note = E4 interval = 0.125
# state [239] note = D4 interval = 0.25
# state [240] note = A3 interval = 0.25
# state [241] note = C4 interval = 0.25
# state [242] note = D4 interval = 0.125
# state [243] note = D4 interval = 0.25
# state [244] note = D4 interval = 0.125
# state [245] note = D4 interval = 0.125
# state [246] note = C4 interval = 0.125
# state [247] note = A3 interval = 0.125
# state [248] note = A3 interval = 0.25
# state [249] note = C4 interval = 0.25
# state [250] note = C4 interval = 0.125
# state [251] note = D4 interval = 0.125
# state [252] note = D4 interval = 2.875
# state [253] note = D4 interval = 0.125
# state [254] note = D4 interval = 0.125
# state [255] note = C4 interval = 0.125
# state [256] note = D4 interval = 0.25
# state [257] note = D4 interval = 0.125
# state [258] note = E4 interval = 0.125
# state [259] note = D4 interval = 0.125
# state [260] note = C4 interval = 0.125
# state [261] note = C4 interval = 0.125
# state [262] note = D4 interval = 0.125
# state [263] note = D4 interval = 0.25
# state [264] note = D4 interval = 0.25
# state [265] note = D4 interval = 0.125
# state [266] note = C4 interval = 0.125
# state [267] note = C4 interval = 0.125
# state [268] note = C4 interval = 0.125
# state [269] note = A3 interval = 0.125
# state [270] note = G3 interval = 0.125
# state [271] note = A3 interval = 0.125
# state [272] note = G3 interval = 0.125
# state [273] note = C4 interval = 0.125
# state [274] note = C4 interval = 0.125
# state [275] note = C4 interval = 0.125
# state [276] note = A3 interval = 0.125
# state [277] note = A3 interval = 0.125
# state [278] note = C4 interval = 0.125
# state [279] note = A3 interval = 0.125
# state [280] note = G3 interval = 0.125
# state [281] note = C4 interval = 0.125
# state [282] note = C4 interval = 0.375
# state [283] note = A4 interval = 0.16666666666666666
# state [284] note = A4 interval = 0.5
# state [285] note = C4 interval = 0.25
# state [286] note = D4 interval = 0.125
# state [287] note = E4 interval = 0.125
# state [288] note = D4 interval = 0.125
# state [289] note = D4 interval = 0.875
# state [290] note = D4 interval = 0.125
# state [291] note = D4 interval = 0.25
# state [292] note = D4 interval = 0.125
# state [293] note = A3 interval = 0.125
# state [294] note = G3 interval = 0.125
# state [295] note = C4 interval = 0.125
# state [296] note = C4 interval = 0.125
# state [297] note = D4 interval = 0.125
# state [298] note = C4 interval = 0.125
# state [299] note = D4 interval = 0.125
# state [300] note = C4 interval = 0.125
# state [301] note = C4 interval = 0.125
# state [302] note = C4 interval = 0.25
# state [303] note = D4 interval = 0.125
# state [304] note = E4 interval = 0.125
# state [305] note = E4 interval = 0.25
# state [306] note = D4 interval = 0.125
# state [307] note = C4 interval = 0.125
# state [308] note = E4 interval = 0.25
# state [309] note = D4 interval = 0.125
# state [310] note = D4 interval = 0.625
# state [311] note = C5 interval = 0.625
# state [312] note = C4 interval = 0.125
# state [313] note = C4 interval = 0.125
# state [314] note = A3 interval = 0.125
# state [315] note = A3 interval = 0.125
# state [316] note = A3 interval = 0.375
# state [317] note = D3 interval = 0.125
# state [318] note = D3 interval = 0.125
# state [319] note = D3 interval = 0.125
# state [320] note = D3 interval = 0.125
# state [321] note = D3 interval = 0.125
# state [322] note = D3 interval = 0.125
# state [323] note = E3 interval = 1.25
# state [324] note = D4 interval = 0.08333333333333333
# state [325] note = D4 interval = 0.125
# state [326] note = C4 interval = 0.125
# state [327] note = A3 interval = 0.125
# state [328] note = C4 interval = 0.875
# state [329] note = D4 interval = 0.125
# state [330] note = C4 interval = 0.125
# state [331] note = A3 interval = 0.125
# state [332] note = G3 interval = 0.125
# state [333] note = C4 interval = 0.125
# state [334] note = A3 interval = 0.125
# state [335] note = G3 interval = 0.125
# state [336] note = A3 interval = 0.125
# state [337] note = A3 interval = 0.125
# state [338] note = A3 interval = 0.125
# state [339] note = A3 interval = 0.125
# state [340] note = G3 interval = 0.125
# state [341] note = A3 interval = 0.125
# state [342] note = A3 interval = 0.125
# state [343] note = A3 interval = 0.125
# state [344] note = A3 interval = 0.125
# state [345] note = A3 interval = 0.125
# state [346] note = G3 interval = 0.125
# state [347] note = C4 interval = 0.125
# state [348] note = D4 interval = 0.08333333333333333
# state [349] note = C4 interval = 0.08333333333333333
# state [350] note = A3 interval = 0.08333333333333333
# state [351] note = A3 interval = 0.25
# state [352] note = C4 interval = 0.25
# state [353] note = D4 interval = 0.125
# state [354] note = E4 interval = 0.125
# state [355] note = D4 interval = 0.125
# state [356] note = A3 interval = 0.125
# state [357] note = A3 interval = 0.125
# state [358] note = A3 interval = 0.125
# state [359] note = G3 interval = 0.125
# state [360] note = A3 interval = 0.125
# state [361] note = A3 interval = 0.25
# state [362] note = C4 interval = 0.125
# state [363] note = D4 interval = 0.125
# state [364] note = A3 interval = 0.125
# state [365] note = A3 interval = 0.125
# state [366] note = C4 interval = 0.125
# state [367] note = A3 interval = 0.25
# state [368] note = C4 interval = 0.125
# state [369] note = B3 interval = 0.375
# state [370] note = D4 interval = 0.125
# state [371] note = D4 interval = 0.5
# state [372] note = E4 interval = 0.25
# state [373] note = E4 interval = 0.25
# state [374] note = D4 interval = 0.125
# state [375] note = E4 interval = 0.125
# state [376] note = D4 interval = 0.125
# state [377] note = C4 interval = 0.125
# state [378] note = A3 interval = 0.125
# state [379] note = G3 interval = 0.125
# state [380] note = A3 interval = 0.125
# state [381] note = A3 interval = 0.375
# state [382] note = D3 interval = 0.125
# state [383] note = E3 interval = 0.5
# state [384] note = C4 interval = 0.25
# state [385] note = C4 interval = 0.16666666666666666
# state [386] note = D4 interval = 0.16666666666666666
# state [387] note = E4 interval = 0.41666666666666663
# state [388] note = C4 interval = 0.25
# state [389] note = C4 interval = 0.16666666666666666
# state [390] note = D4 interval = 0.16666666666666666
# state [391] note = E4 interval = 0.41666666666666663
# state [392] note = E5 interval = 0.5
# state [393] note = D5 interval = 0.08333333333333333
# state [394] note = C5 interval = 0.08333333333333333
# state [395] note = A4 interval = 0.08333333333333333
# state [396] note = A4 interval = 0.125
# state [397] note = C5 interval = 0.125
# state [398] note = D5 interval = 0.08333333333333333
# state [399] note = E5 interval = 0.08333333333333333
# state [400] note = D5 interval = 0.08333333333333333
# state [401] note = D5 interval = 0.125
# state [402] note = C5 interval = 0.125
# state [403] note = D5 interval = 0.125
# state [404] note = E5 interval = 0.125
# state [405] note = D5 interval = 0.25
# state [406] note = C5 interval = 0.125
# state [407] note = C5 interval = 0.125
# state [408] note = A4 interval = 0.59375
# state [409] note = E4 interval = 0.125
# state [410] note = D4 interval = 0.125
# state [411] note = C4 interval = 0.125
# state [412] note = A3 interval = 0.125
# state [413] note = G3 interval = 0.125
# state [414] note = A3 interval = 0.125
# state [415] note = C4 interval = 0.125
# state [416] note = D4 interval = 0.125
# state [417] note = C4 interval = 0.125
# state [418] note = A3 interval = 0.125
# state [419] note = A3 interval = 0.25
# state [420] note = C4 interval = 0.125
# state [421] note = A3 interval = 0.125
# state [422] note = A3 interval = 0.125
# state [423] note = G3 interval = 0.125
# state [424] note = C4 interval = 0.125
# state [425] note = C4 interval = 0.125
# state [426] note = A3 interval = 0.125
# state [427] note = G3 interval = 0.125
# state [428] note = A3 interval = 0.125
# state [429] note = A3 interval = 0.125
# state [430] note = A3 interval = 0.125
# state [431] note = A3 interval = 0.125
# state [432] note = G3 interval = 0.125
# state [433] note = A3 interval = 0.125
# state [434] note = A3 interval = 0.125
# state [435] note = A3 interval = 0.125
# state [436] note = A3 interval = 0.5
# state [437] note = E4 interval = 0.25
# state [438] note = D4 interval = 0.125
# state [439] note = A3 interval = 0.125
# state [440] note = C4 interval = 0.875
# state [441] note = D4 interval = 0.125
# state [442] note = C4 interval = 0.125
# state [443] note = D4 interval = 0.125
# state [444] note = C4 interval = 0.125
# state [445] note = A3 interval = 0.125
# state [446] note = A3 interval = 0.125
# state [447] note = A3 interval = 0.125
# state [448] note = A3 interval = 0.125
# state [449] note = G3 interval = 0.125
# state [450] note = C4 interval = 0.125
# state [451] note = C4 interval = 0.125
# state [452] note = A3 interval = 0.125
# state [453] note = G3 interval = 0.125
# state [454] note = A3 interval = 0.125
# state [455] note = A3 interval = 0.125
# state [456] note = A3 interval = 0.125
# state [457] note = A3 interval = 0.125
# state [458] note = G3 interval = 0.125
# state [459] note = A3 interval = 0.125
# state [460] note = A3 interval = 0.125
# state [461] note = A3 interval = 0.125
# state [462] note = A3 interval = 0.5
# state [463] note = E4 interval = 0.25
# state [464] note = D4 interval = 0.125
# state [465] note = A3 interval = 0.125
# state [466] note = C4 interval = 0.875
# state [467] note = D4 interval = 0.125
# state [468] note = C4 interval = 0.125
# state [469] note = D4 interval = 0.125
# state [470] note = C4 interval = 0.125
# state [471] note = A3 interval = 0.125
# state [472] note = A3 interval = 0.125
# state [473] note = A3 interval = 0.125
# state [474] note = A3 interval = 0.125
# state [475] note = A3 interval = 0.125
# state [476] note = C4 interval = 0.375
# state [477] note = A3 interval = 0.125
# state [478] note = A3 interval = 0.125
# state [479] note = A3 interval = 0.125
# state [480] note = A3 interval = 0.125
# state [481] note = C4 interval = 0.875
# state [482] note = D4 interval = 0.125
# state [483] note = C4 interval = 0.125
# state [484] note = D4 interval = 0.125
# state [485] note = C4 interval = 0.125
# state [486] note = C4 interval = 0.125
# state [487] note = D4 interval = 0.125
# state [488] note = E4 interval = 0.125
# state [489] note = D4 interval = 0.25
# state [490] note = A3 interval = 0.25
# state [491] note = C4 interval = 0.125
# state [492] note = A3 interval = 0.125
# state [493] note = A3 interval = 0.25
# state [494] note = C4 interval = 0.25
# state [495] note = A3 interval = 0.125
# state [496] note = G3 interval = 0.125
# state [497] note = C5 interval = 0.125
# state [498] note = E5 interval = 0.125
# state [499] note = D5 interval = 0.25
# state [500] note = C5 interval = 0.125
# state [501] note = C5 interval = 0.125
# state [502] note = D5 interval = 0.25
# state [503] note = G4 interval = 0.375
# state [504] note = C4 interval = 0.125
# state [505] note = A3 interval = 0.125
# state [506] note = G3 interval = 0.125
# state [507] note = A3 interval = 0.125
# state [508] note = G3 interval = 0.125
# state [509] note = C4 interval = 0.125
# state [510] note = D4 interval = 0.125
# state [511] note = C4 interval = 0.125
# state [512] note = C4 interval = 0.125
# state [513] note = D4 interval = 0.08333333333333333
# state [514] note = E4 interval = 0.08333333333333333
# state [515] note = D4 interval = 0.08333333333333333
# state [516] note = E4 interval = 0.08333333333333333
# state [517] note = D4 interval = 0.08333333333333333
# state [518] note = C4 interval = 0.08333333333333333
# state [519] note = A3 interval = 0.08333333333333333
# state [520] note = A3 interval = 0.25
# state [521] note = C4 interval = 0.25
# state [522] note = D4 interval = 0.125
# state [523] note = C4 interval = 0.125
# state [524] note = D4 interval = 0.125
# state [525] note = C4 interval = 0.125
# state [526] note = C4 interval = 0.125
# state [527] note = G3 interval = 0.125
# state [528] note = C4 interval = 0.125
# state [529] note = A3 interval = 0.125
# state [530] note = G3 interval = 0.125
# state [531] note = A3 interval = 0.125
# state [532] note = A3 interval = 0.125
# state [533] note = A3 interval = 0.125
# state [534] note = A3 interval = 0.125
# state [535] note = G3 interval = 0.125
# state [536] note = A3 interval = 0.125
# state [537] note = A3 interval = 0.125
# state [538] note = A3 interval = 0.125
# state [539] note = A3 interval = 0.125
# state [540] note = A3 interval = 0.125
# state [541] note = G3 interval = 0.125
# state [542] note = C4 interval = 0.125
# state [543] note = D4 interval = 0.08333333333333333
# state [544] note = C4 interval = 0.08333333333333333
# state [545] note = A3 interval = 0.08333333333333333
# state [546] note = A3 interval = 0.25
# state [547] note = C4 interval = 0.25
# state [548] note = D4 interval = 0.125
# state [549] note = E4 interval = 0.125
# state [550] note = D4 interval = 0.125
# state [551] note = A3 interval = 0.125
# state [552] note = A3 interval = 0.125
# state [553] note = A3 interval = 0.125
# state [554] note = G3 interval = 0.125
# state [555] note = A3 interval = 0.125
# state [556] note = A3 interval = 0.25
# state [557] note = C4 interval = 0.125
# state [558] note = D4 interval = 0.125
# state [559] note = A3 interval = 0.125
# state [560] note = A3 interval = 0.125
# state [561] note = C4 interval = 0.125
# state [562] note = A3 interval = 0.25
# state [563] note = C4 interval = 0.125
# state [564] note = B3 interval = 0.375
# state [565] note = D4 interval = 0.125
# state [566] note = D4 interval = 0.5
# state [567] note = E4 interval = 0.25
# state [568] note = E4 interval = 0.25
# state [569] note = D4 interval = 0.125
# state [570] note = E4 interval = 0.125
# state [571] note = D4 interval = 0.125
# state [572] note = C4 interval = 0.125
# state [573] note = A3 interval = 0.125
# state [574] note = G3 interval = 0.125
# state [575] note = A3 interval = 0.125
# state [576] note = A3 interval = 0.375
# state [577] note = D3 interval = 0.125
# state [578] note = E3 interval = 0.5
# state [579] note = C4 interval = 0.25
# state [580] note = C4 interval = 0.16666666666666666
# state [581] note = D4 interval = 0.16666666666666666
# state [582] note = E4 interval = 0.41666666666666663
# state [583] note = C4 interval = 0.25
# state [584] note = C4 interval = 0.16666666666666666
# state [585] note = D4 interval = 0.16666666666666666
# state [586] note = E4 interval = 0.41666666666666663
# state [587] note = E5 interval = 0.5
# state [588] note = D5 interval = 0.08333333333333333
# state [589] note = C5 interval = 0.08333333333333333
# state [590] note = A4 interval = 0.08333333333333333
# state [591] note = A4 interval = 0.125
# state [592] note = C5 interval = 0.125
# state [593] note = D5 interval = 0.08333333333333333
# state [594] note = E5 interval = 0.08333333333333333
# state [595] note = D5 interval = 0.08333333333333333
# state [596] note = D5 interval = 0.125
# state [597] note = C5 interval = 0.125
# state [598] note = D5 interval = 0.125
# state [599] note = E5 interval = 0.125
# state [600] note = D5 interval = 0.25
# state [601] note = C5 interval = 0.125
# state [602] note = C5 interval = 0.125
# state [603] note = A4 interval = 0.59375
# state [604] note = E4 interval = 0.125
# state [605] note = D4 interval = 0.125
# state [606] note = C4 interval = 0.125
# state [607] note = A3 interval = 0.125
# state [608] note = G3 interval = 0.125
# state [609] note = A3 interval = 0.125
# state [610] note = C4 interval = 0.125
# state [611] note = D4 interval = 0.125
# state [612] note = C4 interval = 0.125
# state [613] note = A3 interval = 0.125
# state [614] note = A3 interval = 0.25
# state [615] note = C4 interval = 0.125
# state [616] note = A3 interval = 0.125
# state [617] note = A3 interval = 0.125
# state [618] note = C4 interval = 0.375
# state [619] note = A4 interval = 0.16666666666666666
# state [620] note = A4 interval = 0.16666666666666666
# state [621] note = A4 interval = 0.16666666666666666
# state [622] note = A4 interval = 0.5
# state [623] note = C4 interval = 0.25
# state [624] note = D4 interval = 0.125
# state [625] note = C4 interval = 0.125
# state [626] note = A3 interval = 0.125
# state [627] note = A3 interval = 0.125
# state [628] note = A3 interval = 0.25
# state [629] note = C4 interval = 0.125
# state [630] note = C4 interval = 0.125
# state [631] note = C4 interval = 0.125
# state [632] note = D4 interval = 0.125
# state [633] note = C4 interval = 0.125
# state [634] note = C4 interval = 0.25
# state [635] note = D4 interval = 0.125
# state [636] note = C4 interval = 0.125
# state [637] note = Eb4 interval = 0.25
# state [638] note = D4 interval = 0.125
# state [639] note = C4 interval = 0.125
# state [640] note = C4 interval = 0.125
# state [641] note = C4 interval = 0.125
# state [642] note = A3 interval = 0.125
# state [643] note = A3 interval = 0.125
# state [644] note = A3 interval = 0.125
# state [645] note = C4 interval = 1.125
# state [646] note = C4 interval = 0.125
# state [647] note = C4 interval = 0.125
# state [648] note = D4 interval = 0.125
# state [649] note = D4 interval = 0.25
# state [650] note = D4 interval = 0.125
# state [651] note = C4 interval = 0.125
# state [652] note = A3 interval = 0.125
# state [653] note = A3 interval = 0.125
# state [654] note = G3 interval = 0.125
# state [655] note = C4 interval = 0.125
# state [656] note = C4 interval = 0.125
# state [657] note = D4 interval = 0.125
# state [658] note = C4 interval = 0.125
# state [659] note = A3 interval = 0.125
# state [660] note = C4 interval = 0.125
# state [661] note = D4 interval = 0.125
# state [662] note = E4 interval = 0.125
# state [663] note = D4 interval = 0.125
# state [664] note = C4 interval = 0.125
# state [665] note = C4 interval = 0.125
# state [666] note = D4 interval = 0.125

# %%
play(DBMR, bpm = 136)

# %%
#print(DBMR)

# %%
#print(DBMR.notes)

# %%
#print(DBMR.interval)

# %%
#DBMR.analyze_rhythm()

# %% [markdown]
# #### Analysis of Random Song

# %% [markdown]
# Only the notes:

# %%
def PlotNoteFrequencies(NoteList):
    
    # Order notes
    note_order = ['A3', 'A4', 'B3', 'C4', 'C5', 'D3', 'D4', 'D5', 'Eb4', 'E3', 'E4', 'E5', 'G3', 'G4']
    
    # Creating an empty dictionary
    SongDict = {}
 
    # Set assign the notes as dictionary keys: 
    for note in note_order:
        SongDict[note] = 0
        
    # Loop over the given note list again to give a value to the number of occurances. 
    for note in NoteList:
        snote = str(note)
        #print("note",note)
        if snote in SongDict:
            SongDict[snote] = SongDict[snote]+1

    print(SongDict)

    # Sort notes and frequencies
    Notes     = list(SongDict.keys())
    Frequency = [SongDict[note] for note in Notes]
  
    # creating the bar plot
    fig, ax = plt.subplots(figsize = (10, 5))
    bars = ax.bar(Notes, Frequency, color = "silver")
 
    for i in range(len(Notes)):
        ax.text(bars[i].get_x() + bars[i].get_width() / 2, bars[i].get_height(), str(Frequency[i]), ha='center', va='bottom')
       
    plt.xlabel("Note Used")
    plt.ylabel("Frequency in Song")
    plt.title("Frequency of Notes in Newly Generated Don't Blame Me")
    plt.xticks(rotation = 45) 
    plt.show()
    fig.savefig("Random DBM Note Frequencies.png", bbox_inches='tight')

    
PlotNoteFrequencies(DBMR.notes)
# Out:
# {'A3': 172, 'A4': 19, 'B3': 3, 'C4': 175, 'C5': 21, 'D3': 17, 'D4': 136, 'D5': 20, 'Eb4': 4, 'E3': 7, 'E4': 45, 'E5': 10, 'G3': 37, 'G4': 1}

# %% [markdown]
# Notes and their respective length:

# %%
formatted_notes = [' '.join([str(note), str(interval)]) for note, interval in zip(DBMR, DBMR.interval)]
# print(formatted_notes)

# %%
def PlotSpecificNoteFrequencies(NoteList):
           
    # Order specific notes
    specific_note_order = ['A3 0.08333333333333333', 'A3 0.125', 'A3 0.1875', 'A3 0.25', 'A3 0.375', 'A4 0.08333333333333333', 'A4 0.125', 'A4 0.16666666666666666', 'A4 0.1875', 'A4 0.25', 'B3 0.375', 'C4 0.08333333333333333', 'C4 0.125', 'C4 0.16666666666666666', 'C4 0.25', 'C4 0.375', 'C5 0.08333333333333333', 'C5 0.125', 'C5 0.25', 'C5 0.5', 'D3 0.125', 'D3 0.25', 'D4 0.08333333333333333', 'D4 0.125', 'D4 0.16666666666666666', 'D4 0.25', 'D4 0.375', 'D5 0.08333333333333333', 'D5 0.125', 'D5 0.25', 'Eb4 0.25', 'E3 0.25', 'E4 0.08333333333333333', 'E4 0.125', 'E4 0.16666666666666666', 'E4 0.25', 'E5 0.08333333333333333', 'E5 0.125', 'E5 0.25', 'E5 0.5', 'G3 0.125', 'G4 0.25']

    # Creating an empty dictionary
    SongDict = {}
 
    # Set assign the notes as dictionary keys: 
    for note in specific_note_order:
        SongDict[note] = 0

    # Loop over the given note list again to give a value to the number of occurances. 
    for note in NoteList:
        snote = str(note)
#         print("note",note)
        if snote in SongDict:
            SongDict[snote] = SongDict[snote]+1

    print(SongDict)

    # Sort notes and frequencies
    Notes     = list(SongDict.keys())
    Frequency = [SongDict[note] for note in Notes]
  
    # creating the bar plot
    fig, ax = plt.subplots(figsize = (10, 5))
    bars = ax.bar(Notes, Frequency, color = "silver")
    
    for i in range(len(Notes)):
        ax.text(bars[i].get_x() + bars[i].get_width() / 2, bars[i].get_height(), str(Frequency[i]), ha='center', va='bottom')
    
    plt.xlabel("Specific Note Type Used")
    plt.ylabel("Frequency in Song")
    plt.title("Frequency of Specific Note Types in Newly Generated Don't Blame Me")
    plt.xticks(rotation = 88) 
    plt.show()
    fig.savefig("Random DBM Specific Note Type Frequencies.png", bbox_inches='tight')


PlotSpecificNoteFrequencies(formatted_notes)
# Out:
# {'A3 0.08333333333333333': 4, 'A3 0.125': 138, 'A3 0.1875': 0, 'A3 0.25': 21, 'A3 0.375': 6, 'A4 0.08333333333333333': 3, 'A4 0.125': 3, 'A4 0.16666666666666666': 7, 'A4 0.1875': 0, 'A4 0.25': 0, 'B3 0.375': 3, 'C4 0.08333333333333333': 4, 'C4 0.125': 131, 'C4 0.16666666666666666': 6, 'C4 0.25': 22, 'C4 0.375': 3, 'C5 0.08333333333333333': 3, 'C5 0.125': 15, 'C5 0.25': 0, 'C5 0.5': 0, 'D3 0.125': 16, 'D3 0.25': 1, 'D4 0.08333333333333333': 10, 'D4 0.125': 98, 'D4 0.16666666666666666': 6, 'D4 0.25': 13, 'D4 0.375': 1, 'D5 0.08333333333333333': 9, 'D5 0.125': 6, 'D5 0.25': 5, 'Eb4 0.25': 4, 'E3 0.25': 0, 'E4 0.08333333333333333': 2, 'E4 0.125': 21, 'E4 0.16666666666666666': 0, 'E4 0.25': 16, 'E5 0.08333333333333333': 3, 'E5 0.125': 4, 'E5 0.25': 0, 'E5 0.5': 3, 'G3 0.125': 37, 'G4 0.25': 0}

# %% [markdown]
# Length of all notes:

# %%
def PlotNoteLengthFrequencies(LengthList):
    
    # Order lenths
    length_order = ['0.08333333333333333', '0.125', '0.16666666666666666', '0.1875', '0.25', '0.375', '0.5']

    # Creating an empty dictionary
    SongDict = {}
 
    # Set assign the rhythms as dictionary keys: 
    for length in length_order:
        SongDict[length] = 0
        
    # Loop over the given rhythm list again to give a value to the number of occurances. 
    for length in LengthList:
        slength = str(length)
        #print("length",length)
        if slength in SongDict:
            SongDict[slength] = SongDict[slength]+1

    print(SongDict)
    
    # Sort notes and frequencies
    Notes     = list(SongDict.keys())
    Frequency = [SongDict[note] for note in Notes]
 
    # creating the bar plot
    fig, ax = plt.subplots(figsize = (10, 5))
    bars = ax.bar(Notes, Frequency, color = "silver")
    
    for i in range(len(Notes)):
        ax.text(bars[i].get_x() + bars[i].get_width() / 2, bars[i].get_height(), str(Frequency[i]), ha='center', va='bottom')
    
    plt.xlabel("Length of Note")
    plt.ylabel("Frequency in Song")
    plt.title("Frequency of Note Lengths in Newly Generated Don't Blame Me")
    plt.xticks(rotation = 45)
    plt.show()
    fig.savefig("Random DBM Length of Notes Frequencies.png", bbox_inches='tight')

    
PlotNoteLengthFrequencies(DBMR.interval)
# Out:
# {'0.08333333333333333': 38, '0.125': 469, '0.16666666666666666': 19, '0.1875': 0, '0.25': 82, '0.375': 14, '0.5': 15}
